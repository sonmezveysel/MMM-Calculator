# %%
import pandas as pd
import numpy as np

weekly = pd.read_csv("weekly_data.csv")

# %%
weekly.head()
# Out:
#          Week  Month_Year  Promo_Exists  Consumer_Index  Inflation_Rate  \
# 0  2022-12-26  2023-01-01             0           110.7             8.7
# 1  2023-01-02  2023-01-01             0           110.7             8.7
# 2  2023-01-09  2023-01-01             0           110.7             8.7
# 3  2023-01-16  2023-01-01             0           110.7             8.7
# 4  2023-01-23  2023-01-01             0           110.7             8.7
#
#    Gross_Rating_Point  Month   Year   Search_Spend  Display_Spend  ...  \
# 0               80.85      1   2023   26941.203305    1906.090991  ...
# 1               80.85      7  14161  166808.326493   13229.433752  ...
# 2               80.85      7  14161  162841.971583   13422.007154  ...
# 3               80.85      7  14161  171588.266711   13331.426080  ...
# 4               80.85      7  14161  164179.561188   13046.693086  ...
#
#    category_Books  category_Clothing  category_Electronics  category_Home  \
# ...

# %%
weekly_last = weekly.tail(52).reset_index()

# %%
wl = weekly_last.reset_index()
wl["level_0"] = wl["level_0"]+1
wll = wl[["level_0", "revenue"]]
wll.rename(columns={"level_0": "Week"}, inplace=True) 
wll.rename(columns={"revenue": "Revenue"}, inplace=True)
# Out:
# /var/folders/_1/v_rw1r210972pnhxs2ylkp4h0000gn/T/ipykernel_70622/2064763796.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wll.rename(columns={"level_0": "Week"}, inplace=True)
# /var/folders/_1/v_rw1r210972pnhxs2ylkp4h0000gn/T/ipykernel_70622/2064763796.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wll.rename(columns={"revenue": "Revenue"}, inplace=True)

# %%
wll.to_csv("wll.csv", index=True)
