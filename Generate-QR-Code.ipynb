# %%
import qrcode
from PIL import Image
import IPython.display as display

# Generate QR code
qr = qrcode.QRCode(box_size=10, border=4)
qr.add_data("https://mmmcalculator.streamlit.app")
qr.make(fit=True)

# Convert to image
img = qr.make_image(fill="black", back_color="white")

# Display in Jupyter Notebook
display.display(img)

# %%
# Generate QR code
qr2 = qrcode.QRCode(box_size=10, border=4)
qr.add_data("")
qr.make(fit=True)

# Convert to image
img = qr.make_image(fill="black", back_color="white")

# Display in Jupyter Notebook
display.display(img)
